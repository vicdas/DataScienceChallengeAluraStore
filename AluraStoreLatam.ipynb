# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
tienda
# Out:
#                Producto Categoría del Producto     Precio  Costo de envío  \
# 0     Asistente virtual           Electrónicos   164300.0          6900.0
# 1       Mesa de comedor                Muebles   192300.0          8400.0
# 2         Juego de mesa               Juguetes   209600.0         15900.0
# 3            Microondas      Electrodomésticos   757500.0         41000.0
# 4      Silla de oficina                Muebles   335200.0         20200.0
# ...                 ...                    ...        ...             ...
# 2354          Iphone 15           Electrónicos  1284400.0         66600.0
# 2355          Impresora           Electrónicos   282800.0         15300.0
# 2356      Juego de mesa               Juguetes   122900.0          7200.0
# 2357           Cama box                Muebles   691300.0         35000.0
# 2358         Smartwatch           Electrónicos   195000.0          8600.0
#
#      Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# ...

# %%
# Para calcular el total de una tienda Uno
# Primero calcular la facturación por fila
tienda['Facturación'] = tienda['Precio'] + tienda['Costo de envío']
# Posteriormrnte calcular el total de facturación
facturacion_total_T1 = tienda['Facturación'].sum()
#Revisar el total de facturación de la tienda
print(f"Facturación total de la tienda 1: {facturacion_total_T1}")

# Para calcular el total de una tienda Dos
# Primero calcular la facturación por fila
tienda2['Facturación'] = tienda2['Precio'] + tienda2['Costo de envío']
# Posteriormrnte calcular el total de facturación
facturacion_total_T2 = tienda2['Facturación'].sum()
#Revisar el total de facturación de la tienda
print(f"Facturación total de la tienda 2: {facturacion_total_T2}")

# Para calcular el total de una tienda Tres
# Primero calcular la facturación por fila
tienda3['Facturación'] = tienda3['Precio'] + tienda3['Costo de envío']
# Posteriormrnte calcular el total de facturación
facturacion_total_T3 = tienda3['Facturación'].sum()
#Revisar el total de facturación de la tienda
print(f"Facturación total de la tienda 3: {facturacion_total_T3}")

# Para calcular el total de una tienda Cuatro
# Primero calcular la facturación por fila
tienda4['Facturación'] = tienda4['Precio'] + tienda4['Costo de envío']
# Posteriormrnte calcular el total de facturación
facturacion_total_T4 = tienda4['Facturación'].sum()
#Revisar el total de facturación de la tienda
print(f"Facturación total de la tienda 4: {facturacion_total_T4}")
# Out:
# Facturación total de la tienda 1: 1212258300.0
# Facturación total de la tienda 2: 1175828600.0
# Facturación total de la tienda 3: 1156536200.0
# Facturación total de la tienda 4: 1093693100.0

# %%
if facturacion_total_T1 > facturacion_total_T2:
  if facturacion_total_T1 > facturacion_total_T3:
    if facturacion_total_T1 > facturacion_total_T4:
      Vende_mas = "La tienda con mayor facturación es la tienda 1"
elif facturacion_total_T1 < facturacion_total_T2:
  if facturacion_total_T2 > facturacion_total_T3:
    if facturacion_total_T3 > facturacion_total_T4:
      Vende_mas = "La tienda con mayor facturación es la tienda 2"
    elif facturacion_total_T3 < facturacion_total_T4:
      Vende_mas = "La tienda con mayor facturación es la tienda 4"
    else:
        Vende_mas = "Las tiendas 3 y 4 tienen la mayor facturación"
  elif facturacion_total_T2 < facturacion_total_T3:
    if facturacion_total_T3 > facturacion_total_T4:
      Vende_mas = "La tienda con mayor facturación es la tienda 3"
    elif facturacion_total_T3 < facturacion_total_T4:
      Vende_mas = "La tienda con mayor facturación es la tienda 4"
    else:
      Vende_mas = "Las tiendas 3 y 4 tienen la mayor facturación"
elif facturacion_total_T2 > facturacion_total_T1:
  Vende_mas = "Las tiendas 1 y 2 tienen la mayor facturación"
#Revisar la tienda que vende más
print(Vende_mas)
# Out:
# La tienda con mayor facturación es la tienda 1

# %% [markdown]
# # 2. Ventas por categoría

# %%
# Contar la cantidad de productos vendidos por categoría en la tienda
categorias_mas_vendidas = tienda['Categoría del Producto'].value_counts()
# Mostrar la categoría y ka cantidad más vendida en la tienda
categoria_top = categorias_mas_vendidas.idxmax()
cantidad_top = categorias_mas_vendidas.max()
#Revisar la categoría y la cantidad de productos vendidos en la tienda
print(f"La categoría más vendida en la tienda 1 es: {categoria_top} con {cantidad_top} ventas.")

# Contar la cantidad de productos vendidos por categoría en la tienda
categorias_mas_vendidas = tienda2['Categoría del Producto'].value_counts()
# Mostrar la categoría y ka cantidad más vendida en la tienda
categoria_top = categorias_mas_vendidas.idxmax()
cantidad_top = categorias_mas_vendidas.max()
#Revisar la categoría y la cantidad de productos vendidos en la tienda
print(f"La categoría más vendida en la tienda 2 es: {categoria_top} con {cantidad_top} ventas.")

# Contar la cantidad de productos vendidos por categoría en la tienda
categorias_mas_vendidas = tienda3['Categoría del Producto'].value_counts()
# Mostrar la categoría y ka cantidad más vendida en la tienda
categoria_top = categorias_mas_vendidas.idxmax()
cantidad_top = categorias_mas_vendidas.max()
#Revisar la categoría y la cantidad de productos vendidos en la tienda
print(f"La categoría más vendida en la tienda 3 es: {categoria_top} con {cantidad_top} ventas.")

# Contar la cantidad de productos vendidos por categoría en la tienda
categorias_mas_vendidas = tienda4['Categoría del Producto'].value_counts()
# Mostrar la categoría y ka cantidad más vendida en la tienda
categoria_top = categorias_mas_vendidas.idxmax()
cantidad_top = categorias_mas_vendidas.max()
#Revisar la categoría y la cantidad de productos vendidos en la tienda
print(f"La categoría más vendida en la tienda 4 es: {categoria_top} con {cantidad_top} ventas.")
# Out:
# La categoría más vendida en la tienda 1 es: Muebles con 465 ventas.
# La categoría más vendida en la tienda 2 es: Muebles con 442 ventas.
# La categoría más vendida en la tienda 3 es: Muebles con 499 ventas.
# La categoría más vendida en la tienda 4 es: Muebles con 480 ventas.

# %%
# Calcular la facturación por fila de la tienda
tienda['Facturación'] = tienda['Precio'] + tienda['Costo de envío']
# Contar cuántas ventas hubo por categoría de la tienda
ventas_por_categoria = tienda['Categoría del Producto'].value_counts()
# Obtener la categoría más vendida de la tienda
categoria_mas_vendida = ventas_por_categoria.idxmax()
ventas_mas_altas = ventas_por_categoria.max()
# Calcular la facturación total de esa categoría de la tienda
facturacion_categoria = tienda[tienda['Categoría del Producto'] == categoria_mas_vendida]['Facturación'].sum()
#Revisar las ventas por categoría de la tienda
print(f"La categoría más vendida de la tienda 1 es: {categoria_mas_vendida} con {ventas_mas_altas} ventas.")
print(f"Facturación total de la tienda 1 de {categoria_mas_vendida} por: {facturacion_categoria}")

# Calcular la facturación por fila de la tienda
tienda2['Facturación'] = tienda2['Precio'] + tienda2['Costo de envío']
# Contar cuántas ventas hubo por categoría de la tienda
ventas_por_categoria = tienda2['Categoría del Producto'].value_counts()
# Obtener la categoría más vendida de la tienda
categoria_mas_vendida = ventas_por_categoria.idxmax()
ventas_mas_altas = ventas_por_categoria.max()
# Calcular la facturación total de esa categoría de la tienda
facturacion_categoria = tienda2[tienda2['Categoría del Producto'] == categoria_mas_vendida]['Facturación'].sum()
#Revisar las ventas por categoría de la tienda
print(f"La categoría más vendida de la tienda 2 es: {categoria_mas_vendida} con {ventas_mas_altas} ventas.")
print(f"Facturación total de la tienda 2 de {categoria_mas_vendida} por: {facturacion_categoria}")

# Calcular la facturación por fila de la tienda
tienda3['Facturación'] = tienda3['Precio'] + tienda3['Costo de envío']
# Contar cuántas ventas hubo por categoría de la tienda
ventas_por_categoria = tienda3['Categoría del Producto'].value_counts()
# Obtener la categoría más vendida de la tienda
categoria_mas_vendida = ventas_por_categoria.idxmax()
ventas_mas_altas = ventas_por_categoria.max()
# Calcular la facturación total de esa categoría de la tienda
facturacion_categoria = tienda3[tienda3['Categoría del Producto'] == categoria_mas_vendida]['Facturación'].sum()
#Revisar las ventas por categoría de la tienda
print(f"La categoría más vendida de la tienda 3 es: {categoria_mas_vendida} con {ventas_mas_altas} ventas.")
print(f"Facturación total de la tienda 3 de {categoria_mas_vendida} por: {facturacion_categoria}")

# Calcular la facturación por fila de la tienda
tienda4['Facturación'] = tienda4['Precio'] + tienda4['Costo de envío']
# Contar cuántas ventas hubo por categoría de la tienda
ventas_por_categoria = tienda4['Categoría del Producto'].value_counts()
# Obtener la categoría más vendida de la tienda
categoria_mas_vendida = ventas_por_categoria.idxmax()
ventas_mas_altas = ventas_por_categoria.max()
# Calcular la facturación total de esa categoría de la tienda
facturacion_categoria = tienda4[tienda4['Categoría del Producto'] == categoria_mas_vendida]['Facturación'].sum()
#Revisar las ventas por categoría de la tienda
print(f"La categoría más vendida de la tienda 4 es: {categoria_mas_vendida} con {ventas_mas_altas} ventas.")
print(f"Facturación total de la tienda 4 de {categoria_mas_vendida} por: {facturacion_categoria}")
# Out:
# La categoría más vendida de la tienda 1 es: Muebles con 465 ventas.
# Facturación total de la tienda 1 de Muebles por: 197628600.0
# La categoría más vendida de la tienda 2 es: Muebles con 442 ventas.
# Facturación total de la tienda 2 de Muebles por: 185862400.0
# La categoría más vendida de la tienda 3 es: Muebles con 499 ventas.
# Facturación total de la tienda 3 de Muebles por: 211856200.0
# La categoría más vendida de la tienda 4 es: Muebles con 480 ventas.
# Facturación total de la tienda 4 de Muebles por: 202764200.0

# %%
# top de los 5 productos mas vendidos en la tienda
top5_productos = tienda['Producto'].value_counts().head(5)

print("Top 5 productos más vendidos:")
print(top5_productos)
# Out:
# Top 5 productos más vendidos:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64

# %%
# Calcular la facturación por fila de la tienda
tienda['Facturación'] = tienda['Precio'] + tienda['Costo de envío']

# Agrupar por categoría y sumar la facturación de la tienda
ventas_por_categoria = tienda.groupby('Categoría del Producto')['Facturación'].sum()

#Revisar las ventas por categoría
print("Ventas por categoría:")
print(ventas_por_categoria)
# Out:
# Ventas por categoría:
# Categoría del Producto
# Artículos para el hogar     13342200.0
# Deportes y diversión        41411100.0
# Electrodomésticos          383009200.0
# Electrónicos               452457200.0
# Instrumentos musicales      96182900.0
# Juguetes                    18975200.0
# Libros                       9251900.0
# Muebles                    197628600.0
# Name: Facturación, dtype: float64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
# Calcular la calificación promedio
calificacion_promedio = tienda['Calificación'].mean()
#Revisar la calificación promedio de la tienda
print(f"Calificación promedio de los clientes en la tienda 1: {calificacion_promedio:.2f}")

# Calcular la calificación promedio
calificacion_promedio = tienda2['Calificación'].mean()
#Revisar la calificación promedio de la tienda
print(f"Calificación promedio de los clientes en la tienda 2: {calificacion_promedio:.2f}")

# Calcular la calificación promedio
calificacion_promedio = tienda3['Calificación'].mean()
#Revisar la calificación promedio de la tienda
print(f"Calificación promedio de los clientes en la tienda 3: {calificacion_promedio:.2f}")

# Calcular la calificación promedio
calificacion_promedio = tienda4['Calificación'].mean()
#Revisar la calificación promedio de la tienda
print(f"Calificación promedio de los clientes en la tienda 4: {calificacion_promedio:.2f}")
# Out:
# Calificación promedio de los clientes en la tienda 1: 3.98
# Calificación promedio de los clientes en la tienda 2: 4.04
# Calificación promedio de los clientes en la tienda 3: 4.05
# Calificación promedio de los clientes en la tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
# Contar ventas por producto en la tienda
ventas_por_producto = tienda['Producto'].value_counts()
# Producto más vendido en la tienda
producto_mas_vendido = ventas_por_producto.idxmax()
cantidad_mas_vendido = ventas_por_producto.max()
# Producto menos vendido en la trienda
producto_menos_vendido = ventas_por_producto.idxmin()
cantidad_menos_vendido = ventas_por_producto.min()
#Revisar el poducto mas y menos vendido de la tienda
print(f"Producto más vendido de la tienda 1: {producto_mas_vendido} ({cantidad_mas_vendido} ventas)")
print(f"Producto menos vendido de la tienda 1: {producto_menos_vendido} ({cantidad_menos_vendido} venta(s))")

# Contar ventas por producto en la tienda
ventas_por_producto = tienda2['Producto'].value_counts()
# Producto más vendido en la tienda
producto_mas_vendido = ventas_por_producto.idxmax()
cantidad_mas_vendido = ventas_por_producto.max()
# Producto menos vendido en la trienda
producto_menos_vendido = ventas_por_producto.idxmin()
cantidad_menos_vendido = ventas_por_producto.min()
#Revisar el poducto mas y menos vendido de la tienda
print(f"Producto más vendido de la tienda 2: {producto_mas_vendido} ({cantidad_mas_vendido} ventas)")
print(f"Producto menos vendido de la tienda 2: {producto_menos_vendido} ({cantidad_menos_vendido} venta(s))")

# Contar ventas por producto en la tienda
ventas_por_producto = tienda3['Producto'].value_counts()
# Producto más vendido en la tienda
producto_mas_vendido = ventas_por_producto.idxmax()
cantidad_mas_vendido = ventas_por_producto.max()
# Producto menos vendido en la trienda
producto_menos_vendido = ventas_por_producto.idxmin()
cantidad_menos_vendido = ventas_por_producto.min()
#Revisar el poducto mas y menos vendido de la tienda
print(f"Producto más vendido de la tienda 3: {producto_mas_vendido} ({cantidad_mas_vendido} ventas)")
print(f"Producto menos vendido de la tienda 3: {producto_menos_vendido} ({cantidad_menos_vendido} venta(s))")

# Contar ventas por producto en la tienda
ventas_por_producto = tienda4['Producto'].value_counts()
# Producto más vendido en la tienda
producto_mas_vendido = ventas_por_producto.idxmax()
cantidad_mas_vendido = ventas_por_producto.max()
# Producto menos vendido en la trienda
producto_menos_vendido = ventas_por_producto.idxmin()
cantidad_menos_vendido = ventas_por_producto.min()
#Revisar el poducto mas y menos vendido de la tienda
print(f"Producto más vendido de la tienda 4: {producto_mas_vendido} ({cantidad_mas_vendido} ventas)")
print(f"Producto menos vendido de la tienda 4: {producto_menos_vendido} ({cantidad_menos_vendido} venta(s))")
# Out:
# Producto más vendido de la tienda 1: Microondas (60 ventas)
# Producto menos vendido de la tienda 1: Auriculares con micrófono (33 venta(s))
# Producto más vendido de la tienda 2: Iniciando en programación (65 ventas)
# Producto menos vendido de la tienda 2: Juego de mesa (32 venta(s))
# Producto más vendido de la tienda 3: Kit de bancas (57 ventas)
# Producto menos vendido de la tienda 3: Bloques de construcción (35 venta(s))
# Producto más vendido de la tienda 4: Cama box (62 ventas)
# Producto menos vendido de la tienda 4: Guitarra eléctrica (33 venta(s))

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Calcular el envío promedio por tienda
envio_promedio_por_tienda = tienda.groupby('Lugar de Compra')['Costo de envío'].mean().round(2)
#Revisar el envío promedio de la tienda
print("Envío promedio por la tienda 1:")
print(envio_promedio_por_tienda)

# Calcular el envío promedio por tienda
envio_promedio_por_tienda = tienda2.groupby('Lugar de Compra')['Costo de envío'].mean().round(2)
#Revisar el envío promedio de la tienda
print("Envío promedio por la tienda 2:")
print(envio_promedio_por_tienda)

# Calcular el envío promedio por tienda
envio_promedio_por_tienda = tienda3.groupby('Lugar de Compra')['Costo de envío'].mean().round(2)
#Revisar el envío promedio de la tienda
print("Envío promedio por la tienda 3:")
print(envio_promedio_por_tienda)

# Calcular el envío promedio por tienda
envio_promedio_por_tienda = tienda4.groupby('Lugar de Compra')['Costo de envío'].mean().round(2)
#Revisar el envío promedio de la tienda
print("Envío promedio por la tienda 4:")
print(envio_promedio_por_tienda)
# Out:
# Envío promedio por la tienda 1:
# Lugar de Compra
# Armenia          17314.29
# Barranquilla     23708.00
# Bogotá           23815.85
# Bucaramanga      30587.10
# Cali             28827.56
# Cartagena        22624.53
# Cúcuta           40129.41
# Inírida          28460.00
# Leticia          24450.00
# Manizales        29140.00
# Medellín         28207.10
# Neiva            31516.67
# Pasto            35078.26
# Pereira          22403.76
# Riohacha         24357.50
# Santa Marta      22593.75
# Soacha           43420.00
# Valledupar       18766.67
# Villavicencio    34709.09
# Name: Costo de envío, dtype: float64
# Envío promedio por la tienda 2:
# Lugar de Compra
# Armenia          44525.00
# Barranquilla     18660.26
# Bogotá           25997.06
# Bucaramanga      25796.00
# Cali             28312.61
# Cartagena        16181.43
# Cúcuta           26323.73
# Inírida          64900.00
# Leticia          25329.41
# Manizales        13476.92
# Medellín         26701.85
# ...
